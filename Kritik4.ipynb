# %%
import matplotlib.pyplot as plt
import numpy as np

n=100 #the step rate

def gradient_decent(f, learning_rate, base_point):
    
        def deriv(f, base_point): #estimate the derivative of the function f at base_point
            return (f(base_point+10**(-5))-f(base_point))/(10**(-5)) 
        
        x_coords=[base_point] #List to store the x_n's
        y_coords=[f(base_point)] #List to store the y_n's
        
        point=base_point-learning_rate*deriv(f, base_point) #initialize point
       
        for i in range(n):
            x_coords.append(point)
            y_coords.append(f(point)) # add the points to the lists every time you go through
            point=point-learning_rate*deriv(f, point) #recompute point
            
            if abs(deriv(f, point))<0.001: #check if derivative is close enough to zero to be at a min
                break
                
        if abs(deriv(f, point))>=0.001: #if you can't find the min
                print ("epic fail")
                
       # plot the graph
        plot_range=np.linspace(min(x_coords)-0.5, max(x_coords)+0.5,10000)
        function_range=[f(i) for i in plot_range]
        plt.plot(plot_range, function_range)
        plt.plot(x_coords, y_coords)
        
        return round(x_coords[-1],3), round(y_coords[-1],3)
        
base_point = -10
learning_rate = 0.5

def f(x): #the function
    return x**2
        
minimum = gradient_decent(f, learning_rate, base_point)
print ("Behold, the min:", minimum)
# Out:
# Behold, the min: (-0.0, 0.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

n=100 #the step rate

def gradient_decent(f, learning_rate, base_point):
    
        def deriv(f, base_point): #estimate the derivative of the function f at base_point
            return (f(base_point+10**(-5))-f(base_point))/(10**(-5)) 
        
        x_coords=[base_point] #List to store the x_n's
        y_coords=[f(base_point)] #List to store the y_n's
        
        point=base_point-learning_rate*deriv(f, base_point) #initialize point
       
        for i in range(n):
            x_coords.append(point)
            y_coords.append(f(point)) # add the points to the lists every time you go through
            point=point-learning_rate*deriv(f, point) #recompute point
            
            if abs(deriv(f, point))<0.001: #check if derivative is close enough to zero to be at a min
                break
                
        if abs(deriv(f, point))>=0.001: #if you can't find the min
                print ("epic fail")
                
       # plot the graph
        plot_range=np.linspace(min(x_coords)-0.5, max(x_coords)+0.5,10000)
        function_range=[f(i) for i in plot_range]
        plt.plot(plot_range, function_range)
        plt.plot(x_coords, y_coords)
        
        return round(x_coords[-1],3), round(y_coords[-1],3)
        
base_point = 0.01
learning_rate = 0.5

def f(x):
    return -3*x**3+10*x**2-5*x-3
        
minimum = gradient_decent(f, learning_rate, base_point)
print ("Behold, the min:", minimum)
# Out:
# Behold, the min: (54516060067.706, -4.8606532324023376e+32)

# %%
import matplotlib.pyplot as plt
import numpy as np

n=100 #the step rate

def gradient_decent(f, learning_rate, base_point):
    
        def deriv(f, base_point): #estimate the derivative of the function f at base_point
            return (f(base_point+10**(-5))-f(base_point))/(10**(-5)) 
        
        x_coords=[base_point] #List to store the x_n's
        y_coords=[f(base_point)] #List to store the y_n's
        
        point=base_point-learning_rate*deriv(f, base_point) #initialize point
       
        for i in range(n):
            x_coords.append(point)
            y_coords.append(f(point)) # add the points to the lists every time you go through
            point=point-learning_rate*deriv(f, point) #recompute point
            
            if abs(deriv(f, point))<0.001: #check if derivative is close enough to zero to be at a min
                break
                
        if abs(deriv(f, point))>=0.001: #if you can't find the min
                print ("epic fail")
                
       # plot the graph
        plot_range=np.linspace(min(x_coords)-0.5, max(x_coords)+0.5,10000)
        function_range=[f(i) for i in plot_range]
        plt.plot(plot_range, function_range)
        plt.plot(x_coords, y_coords)
        
        return round(x_coords[-1],3), round(y_coords[-1],3)
        
base_point = 1
learning_rate = 0.5

def f(x):
    if x>0:
        return x**x
    elif x==0:
        return 1
    else:
        return abs(x)**(x)
        
minimum = gradient_decent(f, learning_rate, base_point)
print ("Behold, the min:", minimum)
# Out:
# Behold, the min: (0.37, 0.692)

# %%
###### GRADIENT DECENT DOES NOT WORK HERE BECAUSE f(x) = |x| IS NOT DIFFERENTIABLE EVERYWHERE ######

import matplotlib.pyplot as plt
import numpy as np

n=100 #the step rate

def gradient_decent(f, learning_rate, base_point):
    
        def deriv(f, base_point): #estimate the derivative of the function f at base_point
            return (f(base_point+10**(-5))-f(base_point))/(10**(-5)) 
        
        x_coords=[base_point] #List to store the x_n's
        y_coords=[f(base_point)] #List to store the y_n's
        
        point=base_point-learning_rate*deriv(f, base_point) #initialize point
       
        for i in range(n):
            x_coords.append(point)
            y_coords.append(f(point)) # add the points to the lists every time you go through
            point=point-learning_rate*deriv(f, point) #recompute point
            
            if abs(deriv(f, point))<0.001: #check if derivative is close enough to zero to be at a min
                break
                
        if abs(deriv(f, point))>=0.001: #if you can't find the min
                print ("epic fail")
                
       # plot the graph
        plot_range=np.linspace(min(x_coords)-0.5, max(x_coords)+0.5,10000)
        function_range=[f(i) for i in plot_range]
        plt.plot(plot_range, function_range)
        plt.plot(x_coords, y_coords)
        
        return round(x_coords[-1],3), round(y_coords[-1],3)
        
base_point = -1
learning_rate = 0.5
        
minimum = gradient_decent(f, learning_rate, base_point)
print ("Behold, the min:", minimum)

def f(x):
    return abs(x)

###### GRADIENT DECENT IS NOT SUPPOSED TO WORK HERE BECAUSE f(x) = |x| IS NOT DIFFERENTIABLE EVERYWHERE ######
#lol it still worked though
# Out:
# epic fail
# Behold, the min: (0.0, 0.0)
